# %% [markdown]
# <a href="https://www.kaggle.com/code/arsseniidonskov/pred-client-out?scriptVersionId=224650387" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/telco-customer-churn/WA_Fn-UseC_-Telco-Customer-Churn.csv

# %%
r = '/kaggle/input/telco-customer-churn/WA_Fn-UseC_-Telco-Customer-Churn.csv'
df = pd.read_csv(r)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # Description of the signs

# %%
#customerID	- Номер покупателя
#gender - Пол покупателя
#SeniorCitizen - 
#Partner- есть ли у покупателя партнер
#Dependents - содержит ли клиент кого либо
#tenure - количество месяцев работы в компании 
#PhoneService - пользуется ли клиент телефонной связью
#MultipleLines - пользуется несколькими операторами связи
#InternetService - Вид подключения
#OnlineSecurity - Интернет безопасность(хз лол)
#OnlineBackup - Тоже хз какая то хуйня
#DeviceProtection - Защита устройства
#TechSupport - Тех поддержка
#StreamingTV - Потоковое телевиденье
#StreamingMovies - Удалить нахуй
#Contract - Важная хуйня (Срок контракта)
#PaperlessBilling - Выставление счета в небумажном виде
#PaymentMethod - Способ оплаты
#MonthlyCharges - Ежемесячный платеж
#TotalCharges - Общая сумма
#Churn - Клиент доволен?

# %% [markdown]
# # EDA

# %%
#Общая статистика
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
#Информация о датасете
df.info
# Out:
# <bound method DataFrame.info of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
#Размерность датасета
df.shape
# Out:
# (7043, 21)

# %%
#Пустые значения
null = df.isnull().sum()
null
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#
dubl = df.duplicated().sum()
dubl
# Out:
# 0

# %%
st = df.columns
st
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
nuniniq = df.nunique()
nuniniq
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
import matplotlib as plt
import seaborn as sns
df['Churn'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Churn'>

# %%
import sklearn as skl
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing

le = LabelEncoder()
df['Churn'] = df['Churn'].astype(str) 
df['Churn'] = le.fit_transform(df['Churn'])
print(df['Churn'].unique())
# Out:
# [0 1]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Churn', hue='Churn', palette='pastel')
plt.title('Распределение оттока по типу контракта')
plt.xlabel('Статус ухода')
plt.ylabel('Количество клиентов')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df['Churn'], fill=True)
plt.title('График плотности вероятности Churn')
plt.xlabel('Churn')
plt.ylabel('Частота')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Рассчет и вывод Churn rate
churn_rate = df['Churn'].mean()
print(churn_rate)
# Out:
# 0.2653698707936959

# %%
le = LabelEncoder()
for column in df.select_dtypes(include=['object']):
    df[column] = le.fit_transform(df[column])
df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
#Исследование взаимосвязей между признаками в виде данных

df_corr = df.corr().abs()
df_corr
# Out:
#                   customerID    gender  SeniorCitizen   Partner  Dependents  \
# customerID          1.000000  0.006288       0.002074  0.026729    0.012823
# gender              0.006288  1.000000       0.001874  0.001808    0.010517
# SeniorCitizen       0.002074  0.001874       1.000000  0.016479    0.211185
# Partner             0.026729  0.001808       0.016479  1.000000    0.452676
# Dependents          0.012823  0.010517       0.211185  0.452676    1.000000
# tenure              0.008035  0.005106       0.016567  0.379697    0.159712
# PhoneService        0.006483  0.006488       0.008576  0.017706    0.001762
# MultipleLines       0.004316  0.006739       0.146185  0.142410    0.024991
# InternetService     0.012407  0.000863       0.032310  0.000891    0.044590
# OnlineSecurity      0.013292  0.015017       0.128221  0.150828    0.152166
# OnlineBackup        0.003334  0.012057       0.013632  0.153130    0.091015
# ...

# %%
#Исследование взаимосвязей между признаками в виде тепловой матрицы
plt.figure(figsize=(20,16))
sns.heatmap(df_corr, annot=True, cmap='coolwarm')
plt.show()

# %%
#Теперь берем конкретные значения и смотрим есть ли у них взаимосвязь
corr_gender_seniorcitizen_churn = df[['gender','SeniorCitizen','Churn']].corr()
print(corr_gender_seniorcitizen_churn)

sns.heatmap(corr_gender_seniorcitizen_churn, annot=True, cmap='coolwarm')
# Out:
#                  gender  SeniorCitizen     Churn
# gender         1.000000      -0.001874 -0.008612
# SeniorCitizen -0.001874       1.000000  0.150889
# Churn         -0.008612       0.150889  1.000000
# <Axes: >

# %% [markdown]
# # Preprocessing

# %%
df = df.drop('customerID',axis=1)

# %%
#Просмотр признаков которые нужны в будущем для обучения модели
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
X = df.drop('Churn',axis=1)
y = df['Churn']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)#Разделение данных для обучения модели

model_f = RandomForestClassifier()
model_f.fit(X_train, y_train)
feature_importance = pd.DataFrame(model_f.feature_importances_, index=X_train.columns, columns=['importance'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Сортировка признаков по важности
feature_importance_sorted = feature_importance.sort_values(by='importance', ascending=False)

plt.style.use('seaborn')
plt.figure(figsize=(12,6))
sns.barplot(
    x='importance',
    y=feature_importance_sorted.index,
    data=feature_importance_sorted,
    palette='viridis'
)
plt.title('Важность признаков', fontsize=16)
plt.xlabel('Важность', fontsize=12)
plt.ylabel('Признаки', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
# Out:
# <ipython-input-63-7c5cc2e055a1>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
top_10 = feature_importance_sorted.head(10)
top_10
# Out:
#                   importance
# MonthlyCharges      0.178507
# tenure              0.177465
# TotalCharges        0.166085
# Contract            0.079000
# PaymentMethod       0.055037
# OnlineSecurity      0.046468
# TechSupport         0.042788
# InternetService     0.027851
# gender              0.027812
# PaperlessBilling    0.024867

# %%
final_df = df[['tenure', 'MonthlyCharges', 'TotalCharges', 'Contract', 
               'PaymentMethod', 'TechSupport', 'OnlineSecurity', 
               'gender', 'InternetService', 'OnlineBackup','Churn']]

final_df
# Out:
#       tenure  MonthlyCharges  TotalCharges  Contract  PaymentMethod  \
# 0          1           29.85          2505         0              2
# 1         34           56.95          1466         1              3
# 2          2           53.85           157         0              3
# 3         45           42.30          1400         1              0
# 4          2           70.70           925         0              2
# ...      ...             ...           ...       ...            ...
# 7038      24           84.80          1597         1              3
# 7039      72          103.20          5698         1              1
# 7040      11           29.60          2994         0              2
# 7041       4           74.40          2660         0              3
# 7042      66          105.65          5407         2              0
#
#       TechSupport  OnlineSecurity  gender  InternetService  OnlineBackup  \
# 0               0               0       0                0             2
# ...

# %%
from sklearn.preprocessing import Normalizer
X = final_df
transformer = Normalizer().fit(X)
transformer.transform(X)
X
# Out:
#       tenure  MonthlyCharges  TotalCharges  Contract  PaymentMethod  \
# 0          1           29.85          2505         0              2
# 1         34           56.95          1466         1              3
# 2          2           53.85           157         0              3
# 3         45           42.30          1400         1              0
# 4          2           70.70           925         0              2
# ...      ...             ...           ...       ...            ...
# 7038      24           84.80          1597         1              3
# 7039      72          103.20          5698         1              1
# 7040      11           29.60          2994         0              2
# 7041       4           74.40          2660         0              3
# 7042      66          105.65          5407         2              0
#
#       TechSupport  OnlineSecurity  gender  InternetService  OnlineBackup  \
# 0               0               0       0                0             2
# ...

# %% [markdown]
# ## Model training

# %% [markdown]
# # LinearRegression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression#Импорт регрессионной регрессии
from sklearn.metrics import mean_absolute_error#Импорт метрики для оценки модели
from sklearn.metrics import mean_squared_error#Импорт метрики для оценки модели
from sklearn.metrics import r2_score#Импорт метрики для оценки модели
from sklearn.metrics import accuracy_score#Импорт метрики для оценки точности модели
from sklearn.metrics import precision_score#Импорт метрики для оценки точности модели
from sklearn.metrics import recall_score#Импорт метрики для оценки точности модели

X = final_df.drop('Churn',axis=1)
y = final_df['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)
lin_reg = LinearRegression().fit(X_train, y_train)

y_pred_lin = lin_reg.predict(X_test)


print(f'Mean absolute error:{mean_absolute_error(y_test, y_pred_lin)}')
print(f'Mean squared  error:{mean_squared_error(y_test, y_pred_lin)}')
print(f'R2 score {r2_score(y_test, y_pred_lin)}')
#y_pred_classes = np.round(y_pred).astype(int)#Округляем предсказанное значение до 0 или 1
print(f'Accuracy:{accuracy_score(y_test, y_pred_classes)}')
print(f'Precision:{ precision_score(y_test, y_pred_classes)}')
print(f'Recall:{recall_score(y_test, y_pred_classes)}')
print('Результат не устроил')
# Out:
# Mean absolute error:0.31454531700487426
# Mean squared  error:0.14194780703603205
# R2 score 0.2726082740891814
# Accuracy:0.8016323633782825
# Precision:0.6812977099236641
# Recall:0.4766355140186916
# Результат не устроил

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


log_reg = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42).fit(X_train_scaled, y_train)



y_pred_log = log_reg.predict(X_test_scaled)


print("Accuracy:", accuracy_score(y_test, y_pred_log))
print("Precision:", precision_score(y_test, y_pred_log))
print("Recall:", recall_score(y_test, y_pred_log))
print("F1-score:", f1_score(y_test, y_pred_log))
print("ROC-AUC:", roc_auc_score(y_test, log_reg.predict_proba(X_test_scaled)[:, 1]))


y_proba = log_reg.predict_proba(X_test_scaled)
y_proba[:5]
# Out:
# Accuracy: 0.7416607523066004
# Precision: 0.508557457212714
# Recall: 0.8331108144192256
# F1-score: 0.6315789473684211
# ROC-AUC: 0.8510115952896112
# array([[0.40582539, 0.59417461],
#        [0.7433811 , 0.2566189 ],
#        [0.97009505, 0.02990495],
#        [0.13281434, 0.86718566],
#        [0.95348863, 0.04651137]])

# %% [markdown]
# # RandomForest

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer, f1_score
from scipy.stats import randint

#Пространство параметров
param_dist = {
    'n_estimators': randint(100, 1000),
    'max_depth': [None, 5, 10, 15, 20],
    'min_samples_split': randint(2, 20),
    'max_features': ['sqrt', 'log2', None],
    'class_weight': ['balanced', None]
}

random_search = RandomizedSearchCV(
    estimator=RandomForestClassifier(random_state=42),
    param_distributions=param_dist,
    n_iter=50, 
    scoring=make_scorer(f1_score), 
    cv=5,  
    n_jobs=-1,  
    random_state=42
)

random_search.fit(X_train_scaled, y_train)

best_rf = random_search.best_estimator_

y_pred_rf = best_rf.predict(X_test_scaled)

print(f'Лучшие параметры:{random_search.best_params_}')
print('\nМетрики:')
print(f'Accuracy: {accuracy_score(y_test, y_pred_rf)}')
print(f'F1-score: {f1_score(y_test, y_pred_rf)}')
print(f'Recall: {recall_score(y_test, y_pred_rf)}')
print(f'Precision: {precision_score(y_test, y_pred_rf)}')
# Out:
# Лучшие параметры: {'class_weight': 'balanced', 'max_depth': 5, 'max_features': None, 'min_samples_split': 10, 'n_estimators': 127}
#
# Метрики:
# Accuracy: 0.7469836763662172
# F1-score: 0.6364099949005609
# Recall: 0.8331108144192256
# Precision: 0.5148514851485149

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

svm = SVC(
    class_weight="balanced",  
    kernel="rbf",             
    C=1.0,                    
    probability=True,         
    random_state=42
).fit(X_train_scaled, y_train)

y_pred_svm = svm.predict(X_test_scaled)

print('\nМетрики:')
print(f'Accuracy: {accuracy_score(y_test, y_pred_svm)}')
print(f'F1-score: {f1_score(y_test, y_pred_svm)}')
print(f'Recall: {recall_score(y_test, y_pred_svm)}')
print(f'Precision: {precision_score(y_test, y_pred_svm)}')
# Out:
# Метрики:
# Accuracy: 0.7462739531582683
# F1-score: 0.6316331787738279
# Recall: 0.8184245660881175
# Precision: 0.514261744966443
